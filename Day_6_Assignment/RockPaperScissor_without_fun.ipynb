# %%
import random


#function to check who is the winner
def toCheckWhoWin(choice1,choice2,name):
    if(choice1=="Rock" and (choice2=="Paper" or choice2=="Scissor")):
        if(choice2=="Paper"):
            print("\nComputer won the game and get one point")
            comScore+=1
        else:
            print("\n",name,"Won the game and get one point")
            playerScore+=1
    elif(choice1=="Paper" and (choice2=="Rock" or choice2=="Scissor")):
        if(choice2=="Scissor"):
            print("\nComputer won the game and get one point")
            comScore+=1
        else:
            print("\n",name,"Won the game and get one point")
            playerScore+=1
    elif(choice1=="Scissor" and (choice2=="Paper" or choice2=="Rock")):
        if(choice2=="Rock"):
            print("\nComputer won the game and get one point")
            comScore+=1
        else:
            print("\n",name,"Won the game and get one point")
            playerScore+=1
    
    print("{}'s score is :{}".format(playerName,playerScore),end="\t")
    print("tha computer's score is :{}".format(comScore))
    
    quite=input("\nIf you want quite the game please press y or Y otherwise n or N ");
    if(quite=="y"):
        exit()
    else:
        toGetValueFromPlayer()
        
#to ger the input from user
def toGetValueFromPlayer():
    playerScore=0
    comScore=0
    playerChoice=input("\nRock (or) Paper (or) Scissor which one you will choose: ")
    temp=playerChoice.capitalize()
    if(temp=="Rock" or temp=="Paper" or temp=="Scissor"):
        print("\nyour choice is ",playerChoice)

        #to generate the random value for computer
        comChoice=random.choice(["Rock","Paper","Scissor"]);
        print("The computer's choice is ",comChoice)

        if(temp==comChoice):
            print("\nThe game is die,No one get the point")
            toCheckWhoWin(temp,comChoice,playerName)
        else:
            toCheckWhoWin(temp,comChoice,playerName)    
    else:
        print("\nPlease enter valid one");

#to get player name
playerName=input("Enter your name: ")
print("\nWelcome ",playerName)

toGetValueFromPlayer()
